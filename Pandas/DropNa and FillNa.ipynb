# %%
import pandas as pd

var = pd.read_csv("D:\\Data Analytics Icube\\Pandas\\Diabetes Missing Data.csv")
var
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
var.dropna(axis=1)
# Out:
#      Pregnant  Diabetes_Pedigree  Age  Class
# 0           6              0.627   50      1
# 1           1              0.351   31      0
# 2           8              0.672   32      1
# 3           1              0.167   21      0
# 4           0              2.288   33      1
# ..        ...                ...  ...    ...
# 763        10              0.171   63      0
# 764         2              0.340   27      0
# 765         5              0.245   30      0
# 766         1              0.349   47      1
# 767         1              0.315   23      0
#
# [768 rows x 4 columns]

# %%
var.dropna(axis=0)
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# 6           3     78.0          50.0       32.0           88.0  31.0
# 8           2    197.0          70.0       45.0          543.0  30.5
# 13          1    189.0          60.0       23.0          846.0  30.1
# ..        ...      ...           ...        ...            ...   ...
# 753         0    181.0          88.0       44.0          510.0  43.3
# 755         1    128.0          88.0       39.0          110.0  36.5
# 760         2     88.0          58.0       26.0           16.0  28.4
# 763        10    101.0          76.0       48.0          180.0  32.9
# 765         5    121.0          72.0       23.0          112.0  26.2
#
#      Diabetes_Pedigree  Age  Class
# 3                0.167   21      0
# 4                2.288   33      1
# ...

# %%
var.dropna(how="any")
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# 6           3     78.0          50.0       32.0           88.0  31.0
# 8           2    197.0          70.0       45.0          543.0  30.5
# 13          1    189.0          60.0       23.0          846.0  30.1
# ..        ...      ...           ...        ...            ...   ...
# 753         0    181.0          88.0       44.0          510.0  43.3
# 755         1    128.0          88.0       39.0          110.0  36.5
# 760         2     88.0          58.0       26.0           16.0  28.4
# 763        10    101.0          76.0       48.0          180.0  32.9
# 765         5    121.0          72.0       23.0          112.0  26.2
#
#      Diabetes_Pedigree  Age  Class
# 3                0.167   21      0
# 4                2.288   33      1
# ...

# %%
var.dropna(how="all")
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0           6    148.0          72.0       35.0            NaN  33.6
# 1           1     85.0          66.0       29.0            NaN  26.6
# 2           8    183.0          64.0        NaN            NaN  23.3
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# ..        ...      ...           ...        ...            ...   ...
# 763        10    101.0          76.0       48.0          180.0  32.9
# 764         2    122.0          70.0       27.0            NaN  36.8
# 765         5    121.0          72.0       23.0          112.0  26.2
# 766         1    126.0          60.0        NaN            NaN  30.1
# 767         1     93.0          70.0       31.0            NaN  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# ...

# %%
var.dropna(subset="Serum_Insulin")
# Out:
#      Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 3           1     89.0          66.0       23.0           94.0  28.1
# 4           0    137.0          40.0       35.0          168.0  43.1
# 6           3     78.0          50.0       32.0           88.0  31.0
# 8           2    197.0          70.0       45.0          543.0  30.5
# 13          1    189.0          60.0       23.0          846.0  30.1
# ..        ...      ...           ...        ...            ...   ...
# 753         0    181.0          88.0       44.0          510.0  43.3
# 755         1    128.0          88.0       39.0          110.0  36.5
# 760         2     88.0          58.0       26.0           16.0  28.4
# 763        10    101.0          76.0       48.0          180.0  32.9
# 765         5    121.0          72.0       23.0          112.0  26.2
#
#      Diabetes_Pedigree  Age  Class
# 3                0.167   21      0
# 4                2.288   33      1
# ...

# %%
var.fillna("Python")
# Out:
#      Pregnant Glucose Diastolic_BP Skin_Fold Serum_Insulin   BMI  \
# 0           6   148.0         72.0      35.0        Python  33.6
# 1           1    85.0         66.0      29.0        Python  26.6
# 2           8   183.0         64.0    Python        Python  23.3
# 3           1    89.0         66.0      23.0          94.0  28.1
# 4           0   137.0         40.0      35.0         168.0  43.1
# ..        ...     ...          ...       ...           ...   ...
# 763        10   101.0         76.0      48.0         180.0  32.9
# 764         2   122.0         70.0      27.0        Python  36.8
# 765         5   121.0         72.0      23.0         112.0  26.2
# 766         1   126.0         60.0    Python        Python  30.1
# 767         1    93.0         70.0      31.0        Python  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# 2                0.672   32      1
# 3                0.167   21      0
# ...

# %%
var.fillna({"Skin_Fold":"Black","Serum_Insulin":"Red"})
# Out:
#      Pregnant  Glucose  Diastolic_BP Skin_Fold Serum_Insulin   BMI  \
# 0           6    148.0          72.0      35.0           Red  33.6
# 1           1     85.0          66.0      29.0           Red  26.6
# 2           8    183.0          64.0     Black           Red  23.3
# 3           1     89.0          66.0      23.0          94.0  28.1
# 4           0    137.0          40.0      35.0         168.0  43.1
# ..        ...      ...           ...       ...           ...   ...
# 763        10    101.0          76.0      48.0         180.0  32.9
# 764         2    122.0          70.0      27.0           Red  36.8
# 765         5    121.0          72.0      23.0         112.0  26.2
# 766         1    126.0          60.0     Black           Red  30.1
# 767         1     93.0          70.0      31.0           Red  30.4
#
#      Diabetes_Pedigree  Age  Class
# 0                0.627   50      1
# 1                0.351   31      0
# 2                0.672   32      1
# ...
